# %% [markdown]
# The intention of this notebook is to check what kind of performance can be achieved with a CNN only network for transfer learning with pretrained weights and additional hidden layer.
#
# The new network would be the old one where I fix all the weights of the pretrained CNN network and then throw away the last layer, do this two times (for wildtype and for mutant sequence), concatenate the output of the three different layers (01, 02, 03 as in the other notebooks) and append a hidden layer and an output neuron.
#
# This is equivalent to defining a fully connected NN with one hidden layer and one output neuron, whose input is the extracted representation from the transfer learning CNN model (since the weights would be fixed). Since setting this up and training it is easyer, this is what I will do.
#
# Additionally I feed it the difference of the mutant & wildtype representations.

# %% [markdown]
# ## Notebook Setup

# %%
#Imports:
import os
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import RepeatedKFold
import time
import datetime

# %%
#Connect to google drive:
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Set up file paths:
data_folder_loc = "gdrive/My Drive/iGEM/Databases/Merck&Co/Data/T1626/cnn_rep_sampler_T1626/"
base_data_folder_loc = "gdrive/My Drive/iGEM/Databases/Merck&Co/Data/T1626/own_baseline_xgboost_T1626/"
table_loc = "gdrive/My Drive/iGEM/Databases/Merck&Co/Models/CNN_Features_Pretrain_Cont/"

y_target_loc = base_data_folder_loc + "y_label_own_baseline_xgboost_T1626.pkl"
X_seq_all_01_loc =  data_folder_loc + "sequence_cnn_rep_all_default_01.csv"
X_seq_all_02_loc =  data_folder_loc + "sequence_cnn_rep_all_default_02.csv"
X_seq_all_03_loc =  data_folder_loc + "sequence_cnn_rep_all_default_03.csv"

print("Folders: ")
print("\t",os.path.isdir(data_folder_loc))
print("\t",os.path.isdir(base_data_folder_loc))
print("\t",os.path.isdir(table_loc))
print("Files: ")
print("\t",os.path.isfile(y_target_loc))
print("\t",os.path.isfile(X_seq_all_01_loc))
print("\t",os.path.isfile(X_seq_all_02_loc))
print("\t",os.path.isfile(X_seq_all_03_loc))
# Out:
# Folders:
# 	 True
# 	 True
# 	 True
# Files:
# 	 True
# 	 True
# 	 True
# 	 True

# %%
#XGBoost
# !pip install xgboost==0.82 #working GPU support
import xgboost as xgb
# Out:
# Requirement already satisfied: xgboost==0.82 in /usr/local/lib/python3.6/dist-packages (0.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from xgboost==0.82) (1.16.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost==0.82) (1.3.0)

# %%
#BayersianOptimization
# !pip install bayesian-optimization
from bayes_opt import BayesianOptimization
# Out:
# Requirement already satisfied: bayesian-optimization in /usr/local/lib/python3.6/dist-packages (1.0.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (0.21.1)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.3.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.16.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (0.12.5)

# %% [markdown]
# ## Prepare Data

# %%
#Just load data
y_label = pd.read_pickle(y_target_loc) 

X_seq_all_01 = pd.read_csv(X_seq_all_01_loc, index_col=0)
X_seq_all_02 = pd.read_csv(X_seq_all_02_loc, index_col=0)
X_seq_all_03 = pd.read_csv(X_seq_all_03_loc, index_col=0)

# %%
X_seq_wt_mut_01 = X_seq_all_01[list(filter(lambda x: "diff_rep" not in x, X_seq_all_01.columns))]
X_seq_wt_mut_02 = X_seq_all_02[list(filter(lambda x: "diff_rep" not in x, X_seq_all_02.columns))]
X_seq_wt_mut_03 = X_seq_all_03[list(filter(lambda x: "diff_rep" not in x, X_seq_all_03.columns))]

# %%
X_seq_wt_mut_01_02_03 = pd.concat([X_seq_wt_mut_01, X_seq_wt_mut_02, X_seq_wt_mut_03], axis=1)

# %% [markdown]
# ## N-Trial nested K-Fold Crossvalidation NN Pretrained Function###

# %%
def n_trial_nested_k_fold_crossvalidation_NN(data_x, data_y, num_trials=7, eval_metric="mae", outer_fold=5, repeated_k_fold_seed=42375, inner_test_split=0.2):  
  print("Trials: ", num_trials)
  print("Evaluation metric: ", eval_metric)
  print("Outer folds: ", outer_fold)
    
  #saves result for each outer cross val
  scores_mae = [] 
  scores_rmse = []
  best_parameters = []

  total_fold_counter = 0
  rkf = RepeatedKFold(n_splits=outer_fold, n_repeats=num_trials, random_state=repeated_k_fold_seed)
  # Main loop for trials and outer outer cross_val
  for train_index, test_index in rkf.split(data_x):
    #Measure runtime
    start_time = time.time()
    
    # Print current status
    print("\nTrial number: ", (total_fold_counter//outer_fold)+1)
    print("Fold number: ", (total_fold_counter%outer_fold)+1)
    total_fold_counter += 1
    
    # Select current train and test data
    X_train, X_test = data_x[train_index], data_x[test_index]
    y_train, y_test = data_y[train_index], data_y[test_index]
    
    # Split training data into train_inner and test_inner 80/20 //for early stopping
    #Train test split
    X_train_inner, X_test_inner, y_train_inner, y_test_inner = train_test_split(X_train, y_train, test_size=inner_test_split, random_state=repeated_k_fold_seed) 
    
    #Define model
    inputs = tf.keras.layers.Input(shape=(X_train_inner.shape[-1],))

    x = tf.keras.layers.Dense(512)(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Dense(1, activation="linear")(x)

    model = tf.keras.Model(inputs=inputs, outputs=x)

    #Compile the model
    model.compile(
      optimizer=tf.train.AdamOptimizer(),
      loss=tf.keras.losses.mean_absolute_error,
      metrics=['mae']
    )
    
    weight_loc = "model_temp.hdf5"

    #Configure how to save model and early stopping
    callbacks_list = [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=weight_loc,
            save_weights_only=True,
            monitor='val_loss', 
            save_best_only=True,
            mode='auto',
            period=1),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                         patience=4, 
                                         mode='auto')
    ]

    history = model.fit(X_train_inner,
                        y_train_inner,
                        validation_data=(X_test_inner,y_test_inner),
                        epochs=25,
                        batch_size=8,
                        callbacks=callbacks_list,
                        verbose=1)
    
    #load the best temporary model
    model.load_weights(weight_loc)
    
    #calculate predictions
    y_pred = model.predict(X_test, batch_size=1024, verbose=1)

    # Report testing and training scores
    scores_mae.append(mean_absolute_error(y_test, y_pred))
    scores_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    print("MAE: ", scores_mae[-1], " RMSE: ",scores_rmse[-1], " Runtime: ", str(datetime.timedelta(seconds=(time.time()-start_time))))
  
  print()
  results = pd.DataFrame(best_parameters)
  results["scores_mae"] = scores_mae
  results["scores_rmse"] = scores_rmse
  return results

# %% [markdown]
# ## Evaluate model

# %% [markdown]
# ### Model fully_connected_512

# %%
data = X_seq_wt_mut_01_02_03

# %%
#define model:

# %% [markdown]
# ```
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3584)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1835520
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,838,081
# Trainable params: 1,837,057
# Non-trainable params: 1,024
# ```

# %%
results = n_trial_nested_k_fold_crossvalidation_NN(X_seq_wt_mut_01_02_03.values, y_label)
# Out:
# Trials:  7
# Evaluation metric:  mae
# Outer folds:  5
#
# Trial number:  1
# Fold number:  1
# Train on 1040 samples, validate on 260 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 4.1555 - mean_absolute_error: 4.1555 - val_loss: 8.8106 - val_mean_absolute_error: 8.8106
# Epoch 2/25
# 1040/1040 [==============================] - 1s 578us/sample - loss: 3.7437 - mean_absolute_error: 3.7437 - val_loss: 5.9877 - val_mean_absolute_error: 5.9877
# Epoch 3/25
# 1040/1040 [==============================] - 1s 577us/sample - loss: 3.7177 - mean_absolute_error: 3.7177 - val_loss: 3.6563 - val_mean_absolute_error: 3.6563
# Epoch 4/25
# 1040/1040 [==============================] - 1s 546us/sample - loss: 3.7154 - mean_absolute_error: 3.7154 - val_loss: 3.6748 - val_mean_absolute_error: 3.6748
# Epoch 5/25
# 1040/1040 [==============================] - 1s 560us/sample - loss: 3.5938 - mean_absolute_error: 3.5938 - val_loss: 3.9438 - val_mean_absolute_error: 3.9438
# Epoch 6/25
# 1040/1040 [==============================] - 1s 558us/sample - loss: 3.6459 - mean_absolute_error: 3.6459 - val_loss: 4.0066 - val_mean_absolute_error: 4.0066
# Epoch 7/25
# 1040/1040 [==============================] - 1s 600us/sample - loss: 3.6012 - mean_absolute_error: 3.6012 - val_loss: 3.4847 - val_mean_absolute_error: 3.4847
# Epoch 8/25
# 1040/1040 [==============================] - 1s 558us/sample - loss: 3.5795 - mean_absolute_error: 3.5795 - val_loss: 3.7009 - val_mean_absolute_error: 3.7009
# Epoch 9/25
# 1040/1040 [==============================] - 1s 566us/sample - loss: 3.5730 - mean_absolute_error: 3.5730 - val_loss: 3.8327 - val_mean_absolute_error: 3.8327
# Epoch 10/25
# 1040/1040 [==============================] - 1s 626us/sample - loss: 3.5595 - mean_absolute_error: 3.5595 - val_loss: 4.0138 - val_mean_absolute_error: 4.0138
# Epoch 11/25
# 1040/1040 [==============================] - 1s 612us/sample - loss: 3.4854 - mean_absolute_error: 3.4854 - val_loss: 3.6817 - val_mean_absolute_error: 3.6817
# 326/326 [==============================] - 0s 1ms/sample
# MAE:  3.5592830141949134  RMSE:  4.901196341564822  Runtime:  0:00:18.491743
#
# Trial number:  1
# Fold number:  2
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 4.0348 - mean_absolute_error: 4.0348 - val_loss: 5.6388 - val_mean_absolute_error: 5.6388
# Epoch 2/25
# 1040/1040 [==============================] - 1s 586us/sample - loss: 3.6647 - mean_absolute_error: 3.6647 - val_loss: 4.4281 - val_mean_absolute_error: 4.4281
# Epoch 3/25
# 1040/1040 [==============================] - 1s 578us/sample - loss: 3.6619 - mean_absolute_error: 3.6619 - val_loss: 4.0212 - val_mean_absolute_error: 4.0212
# Epoch 4/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.5567 - mean_absolute_error: 3.5567 - val_loss: 4.3616 - val_mean_absolute_error: 4.3616
# Epoch 5/25
# 1040/1040 [==============================] - 1s 570us/sample - loss: 3.5555 - mean_absolute_error: 3.5555 - val_loss: 4.0972 - val_mean_absolute_error: 4.0972
# Epoch 6/25
# 1040/1040 [==============================] - 1s 579us/sample - loss: 3.4854 - mean_absolute_error: 3.4854 - val_loss: 3.9554 - val_mean_absolute_error: 3.9554
# Epoch 7/25
# 1040/1040 [==============================] - 1s 573us/sample - loss: 3.4667 - mean_absolute_error: 3.4667 - val_loss: 4.3127 - val_mean_absolute_error: 4.3127
# Epoch 8/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.4255 - mean_absolute_error: 3.4255 - val_loss: 4.1787 - val_mean_absolute_error: 4.1787
# Epoch 9/25
# 1040/1040 [==============================] - 1s 575us/sample - loss: 3.4806 - mean_absolute_error: 3.4806 - val_loss: 4.0165 - val_mean_absolute_error: 4.0165
# Epoch 10/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.5178 - mean_absolute_error: 3.5178 - val_loss: 3.9819 - val_mean_absolute_error: 3.9819
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.5179724080860613  RMSE:  4.645746954628608  Runtime:  0:00:17.947835
#
# Trial number:  1
# Fold number:  3
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 4.0711 - mean_absolute_error: 4.0711 - val_loss: 3.8921 - val_mean_absolute_error: 3.8921
# Epoch 2/25
# 1040/1040 [==============================] - 1s 581us/sample - loss: 3.6881 - mean_absolute_error: 3.6881 - val_loss: 4.2479 - val_mean_absolute_error: 4.2479
# Epoch 3/25
# 1040/1040 [==============================] - 1s 569us/sample - loss: 3.7266 - mean_absolute_error: 3.7266 - val_loss: 4.4895 - val_mean_absolute_error: 4.4895
# Epoch 4/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.6216 - mean_absolute_error: 3.6216 - val_loss: 3.9632 - val_mean_absolute_error: 3.9632
# Epoch 5/25
# 1040/1040 [==============================] - 1s 566us/sample - loss: 3.6013 - mean_absolute_error: 3.6013 - val_loss: 4.1858 - val_mean_absolute_error: 4.1858
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.9464627994674903  RMSE:  5.283763665676268  Runtime:  0:00:15.181728
#
# Trial number:  1
# Fold number:  4
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 4.0531 - mean_absolute_error: 4.0531 - val_loss: 4.0764 - val_mean_absolute_error: 4.0764
# Epoch 2/25
# 1040/1040 [==============================] - 1s 589us/sample - loss: 3.7352 - mean_absolute_error: 3.7352 - val_loss: 3.6525 - val_mean_absolute_error: 3.6525
# Epoch 3/25
# 1040/1040 [==============================] - 1s 594us/sample - loss: 3.5954 - mean_absolute_error: 3.5954 - val_loss: 4.4134 - val_mean_absolute_error: 4.4134
# Epoch 4/25
# 1040/1040 [==============================] - 1s 590us/sample - loss: 3.6249 - mean_absolute_error: 3.6249 - val_loss: 3.7224 - val_mean_absolute_error: 3.7224
# Epoch 5/25
# 1040/1040 [==============================] - 1s 597us/sample - loss: 3.5558 - mean_absolute_error: 3.5558 - val_loss: 3.9838 - val_mean_absolute_error: 3.9838
# Epoch 6/25
# 1040/1040 [==============================] - 1s 575us/sample - loss: 3.5170 - mean_absolute_error: 3.5170 - val_loss: 3.7540 - val_mean_absolute_error: 3.7540
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.838093765909855  RMSE:  5.292146587054087  Runtime:  0:00:16.062715
#
# Trial number:  1
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 3.9254 - mean_absolute_error: 3.9254 - val_loss: 4.1299 - val_mean_absolute_error: 4.1299
# Epoch 2/25
# 1040/1040 [==============================] - 1s 593us/sample - loss: 3.7561 - mean_absolute_error: 3.7561 - val_loss: 3.4890 - val_mean_absolute_error: 3.4890
# Epoch 3/25
# 1040/1040 [==============================] - 1s 614us/sample - loss: 3.6658 - mean_absolute_error: 3.6658 - val_loss: 3.8256 - val_mean_absolute_error: 3.8256
# Epoch 4/25
# 1040/1040 [==============================] - 1s 591us/sample - loss: 3.6562 - mean_absolute_error: 3.6562 - val_loss: 3.6688 - val_mean_absolute_error: 3.6688
# Epoch 5/25
# 1040/1040 [==============================] - 1s 573us/sample - loss: 3.5829 - mean_absolute_error: 3.5829 - val_loss: 3.5430 - val_mean_absolute_error: 3.5430
# Epoch 6/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.6042 - mean_absolute_error: 3.6042 - val_loss: 3.6056 - val_mean_absolute_error: 3.6056
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.8430277447883894  RMSE:  5.223627762513344  Runtime:  0:00:16.446350
#
# Trial number:  2
# Fold number:  1
# Train on 1040 samples, validate on 260 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 4.0139 - mean_absolute_error: 4.0139 - val_loss: 5.4438 - val_mean_absolute_error: 5.4438
# Epoch 2/25
# 1040/1040 [==============================] - 1s 576us/sample - loss: 3.6927 - mean_absolute_error: 3.6927 - val_loss: 5.6485 - val_mean_absolute_error: 5.6485
# Epoch 3/25
# 1040/1040 [==============================] - 1s 711us/sample - loss: 3.6234 - mean_absolute_error: 3.6234 - val_loss: 3.7478 - val_mean_absolute_error: 3.7478
# Epoch 4/25
# 1040/1040 [==============================] - 1s 663us/sample - loss: 3.5872 - mean_absolute_error: 3.5872 - val_loss: 4.3557 - val_mean_absolute_error: 4.3557
# Epoch 5/25
# 1040/1040 [==============================] - 1s 666us/sample - loss: 3.5439 - mean_absolute_error: 3.5439 - val_loss: 3.8212 - val_mean_absolute_error: 3.8212
# Epoch 6/25
# 1040/1040 [==============================] - 1s 673us/sample - loss: 3.5289 - mean_absolute_error: 3.5289 - val_loss: 3.7686 - val_mean_absolute_error: 3.7686
# Epoch 7/25
# 1040/1040 [==============================] - 1s 673us/sample - loss: 3.5017 - mean_absolute_error: 3.5017 - val_loss: 3.9076 - val_mean_absolute_error: 3.9076
# 326/326 [==============================] - 1s 2ms/sample
# MAE:  3.6746853487563826  RMSE:  4.820948095615058  Runtime:  0:00:18.087243
#
# Trial number:  2
# Fold number:  2
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.0851 - mean_absolute_error: 4.0851 - val_loss: 5.8255 - val_mean_absolute_error: 5.8255
# Epoch 2/25
# 1040/1040 [==============================] - 1s 591us/sample - loss: 3.7754 - mean_absolute_error: 3.7754 - val_loss: 5.8424 - val_mean_absolute_error: 5.8424
# Epoch 3/25
# 1040/1040 [==============================] - 1s 604us/sample - loss: 3.7037 - mean_absolute_error: 3.7037 - val_loss: 3.8841 - val_mean_absolute_error: 3.8841
# Epoch 4/25
# 1040/1040 [==============================] - 1s 596us/sample - loss: 3.6117 - mean_absolute_error: 3.6117 - val_loss: 4.1234 - val_mean_absolute_error: 4.1234
# Epoch 5/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.5827 - mean_absolute_error: 3.5827 - val_loss: 3.5708 - val_mean_absolute_error: 3.5708
# Epoch 6/25
# 1040/1040 [==============================] - 1s 595us/sample - loss: 3.5608 - mean_absolute_error: 3.5608 - val_loss: 3.6383 - val_mean_absolute_error: 3.6383
# Epoch 7/25
# 1040/1040 [==============================] - 1s 588us/sample - loss: 3.6121 - mean_absolute_error: 3.6121 - val_loss: 3.9076 - val_mean_absolute_error: 3.9076
# Epoch 8/25
# 1040/1040 [==============================] - 1s 567us/sample - loss: 3.5103 - mean_absolute_error: 3.5104 - val_loss: 4.0174 - val_mean_absolute_error: 4.0174
# Epoch 9/25
# 1040/1040 [==============================] - 1s 583us/sample - loss: 3.5046 - mean_absolute_error: 3.5046 - val_loss: 3.7008 - val_mean_absolute_error: 3.7008
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.8198001159292008  RMSE:  4.97809003604716  Runtime:  0:00:20.420480
#
# Trial number:  2
# Fold number:  3
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 3s 3ms/sample - loss: 3.9889 - mean_absolute_error: 3.9889 - val_loss: 4.2668 - val_mean_absolute_error: 4.2668
# Epoch 2/25
# 1040/1040 [==============================] - 1s 562us/sample - loss: 3.6705 - mean_absolute_error: 3.6705 - val_loss: 4.2085 - val_mean_absolute_error: 4.2085
# Epoch 3/25
# 1040/1040 [==============================] - 1s 559us/sample - loss: 3.5983 - mean_absolute_error: 3.5983 - val_loss: 4.2996 - val_mean_absolute_error: 4.2996
# Epoch 4/25
# 1040/1040 [==============================] - 1s 578us/sample - loss: 3.5995 - mean_absolute_error: 3.5995 - val_loss: 3.9920 - val_mean_absolute_error: 3.9920
# Epoch 5/25
# 1040/1040 [==============================] - 1s 582us/sample - loss: 3.4849 - mean_absolute_error: 3.4849 - val_loss: 3.9730 - val_mean_absolute_error: 3.9730
# Epoch 6/25
# 1040/1040 [==============================] - 1s 554us/sample - loss: 3.4762 - mean_absolute_error: 3.4762 - val_loss: 4.6348 - val_mean_absolute_error: 4.6348
# Epoch 7/25
# 1040/1040 [==============================] - 1s 568us/sample - loss: 3.4880 - mean_absolute_error: 3.4880 - val_loss: 3.8736 - val_mean_absolute_error: 3.8736
# Epoch 8/25
# 1040/1040 [==============================] - 1s 559us/sample - loss: 3.4671 - mean_absolute_error: 3.4671 - val_loss: 4.0083 - val_mean_absolute_error: 4.0083
# Epoch 9/25
# 1040/1040 [==============================] - 1s 559us/sample - loss: 3.4961 - mean_absolute_error: 3.4961 - val_loss: 3.8289 - val_mean_absolute_error: 3.8289
# Epoch 10/25
# 1040/1040 [==============================] - 1s 553us/sample - loss: 3.4202 - mean_absolute_error: 3.4202 - val_loss: 4.1827 - val_mean_absolute_error: 4.1827
# Epoch 11/25
# 1040/1040 [==============================] - 1s 549us/sample - loss: 3.3760 - mean_absolute_error: 3.3760 - val_loss: 3.8400 - val_mean_absolute_error: 3.8400
# Epoch 12/25
# 1040/1040 [==============================] - 1s 540us/sample - loss: 3.3559 - mean_absolute_error: 3.3559 - val_loss: 3.8695 - val_mean_absolute_error: 3.8695
# Epoch 13/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.3458 - mean_absolute_error: 3.3458 - val_loss: 3.8124 - val_mean_absolute_error: 3.8124
# Epoch 14/25
# 1040/1040 [==============================] - 1s 543us/sample - loss: 3.3623 - mean_absolute_error: 3.3623 - val_loss: 4.3610 - val_mean_absolute_error: 4.3610
# Epoch 15/25
# 1040/1040 [==============================] - 1s 561us/sample - loss: 3.3263 - mean_absolute_error: 3.3263 - val_loss: 4.2723 - val_mean_absolute_error: 4.2723
# Epoch 16/25
# 1040/1040 [==============================] - 1s 552us/sample - loss: 3.3913 - mean_absolute_error: 3.3913 - val_loss: 3.9302 - val_mean_absolute_error: 3.9302
# Epoch 17/25
# 1040/1040 [==============================] - 1s 561us/sample - loss: 3.3259 - mean_absolute_error: 3.3259 - val_loss: 4.1837 - val_mean_absolute_error: 4.1837
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.975769631353708  RMSE:  5.313740161960285  Runtime:  0:00:23.818963
#
# Trial number:  2
# Fold number:  4
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 3ms/sample - loss: 4.1527 - mean_absolute_error: 4.1527 - val_loss: 5.5416 - val_mean_absolute_error: 5.5416
# Epoch 2/25
# 1040/1040 [==============================] - 1s 583us/sample - loss: 3.7696 - mean_absolute_error: 3.7696 - val_loss: 3.5973 - val_mean_absolute_error: 3.5973
# Epoch 3/25
# 1040/1040 [==============================] - 1s 541us/sample - loss: 3.7391 - mean_absolute_error: 3.7391 - val_loss: 4.6651 - val_mean_absolute_error: 4.6651
# Epoch 4/25
# 1040/1040 [==============================] - 1s 601us/sample - loss: 3.6879 - mean_absolute_error: 3.6879 - val_loss: 3.6822 - val_mean_absolute_error: 3.6822
# Epoch 5/25
# 1040/1040 [==============================] - 1s 571us/sample - loss: 3.6432 - mean_absolute_error: 3.6432 - val_loss: 4.2376 - val_mean_absolute_error: 4.2376
# Epoch 6/25
# 1040/1040 [==============================] - 1s 563us/sample - loss: 3.6560 - mean_absolute_error: 3.6560 - val_loss: 3.7551 - val_mean_absolute_error: 3.7551
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.9527274939761714  RMSE:  5.051148257220995  Runtime:  0:00:17.634106
#
# Trial number:  2
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 3ms/sample - loss: 4.1877 - mean_absolute_error: 4.1877 - val_loss: 4.4020 - val_mean_absolute_error: 4.4020
# Epoch 2/25
# 1040/1040 [==============================] - 1s 620us/sample - loss: 3.7899 - mean_absolute_error: 3.7899 - val_loss: 4.9505 - val_mean_absolute_error: 4.9505
# Epoch 3/25
# 1040/1040 [==============================] - 1s 661us/sample - loss: 3.7764 - mean_absolute_error: 3.7764 - val_loss: 3.7165 - val_mean_absolute_error: 3.7165
# Epoch 4/25
# 1040/1040 [==============================] - 1s 622us/sample - loss: 3.7183 - mean_absolute_error: 3.7183 - val_loss: 4.2951 - val_mean_absolute_error: 4.2951
# Epoch 5/25
# 1040/1040 [==============================] - 1s 638us/sample - loss: 3.6922 - mean_absolute_error: 3.6922 - val_loss: 3.7639 - val_mean_absolute_error: 3.7639
# Epoch 6/25
# 1040/1040 [==============================] - 1s 635us/sample - loss: 3.6344 - mean_absolute_error: 3.6344 - val_loss: 3.7266 - val_mean_absolute_error: 3.7266
# Epoch 7/25
# 1040/1040 [==============================] - 1s 647us/sample - loss: 3.5873 - mean_absolute_error: 3.5873 - val_loss: 3.6394 - val_mean_absolute_error: 3.6394
# Epoch 8/25
# 1040/1040 [==============================] - 1s 672us/sample - loss: 3.6373 - mean_absolute_error: 3.6373 - val_loss: 3.9532 - val_mean_absolute_error: 3.9532
# Epoch 9/25
# 1040/1040 [==============================] - 1s 653us/sample - loss: 3.5284 - mean_absolute_error: 3.5284 - val_loss: 3.9867 - val_mean_absolute_error: 3.9867
# Epoch 10/25
# 1040/1040 [==============================] - 1s 625us/sample - loss: 3.6280 - mean_absolute_error: 3.6280 - val_loss: 3.9834 - val_mean_absolute_error: 3.9834
# Epoch 11/25
# 1040/1040 [==============================] - 1s 641us/sample - loss: 3.5472 - mean_absolute_error: 3.5472 - val_loss: 3.6785 - val_mean_absolute_error: 3.6785
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.4302508389972726  RMSE:  4.5798430806775965  Runtime:  0:00:21.977016
#
# Trial number:  3
# Fold number:  1
# Train on 1040 samples, validate on 260 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 3ms/sample - loss: 4.0811 - mean_absolute_error: 4.0811 - val_loss: 4.5586 - val_mean_absolute_error: 4.5586
# Epoch 2/25
# 1040/1040 [==============================] - 1s 588us/sample - loss: 3.8329 - mean_absolute_error: 3.8329 - val_loss: 4.0139 - val_mean_absolute_error: 4.0139
# Epoch 3/25
# 1040/1040 [==============================] - 1s 570us/sample - loss: 3.6838 - mean_absolute_error: 3.6838 - val_loss: 4.3490 - val_mean_absolute_error: 4.3490
# Epoch 4/25
# 1040/1040 [==============================] - 1s 576us/sample - loss: 3.6579 - mean_absolute_error: 3.6579 - val_loss: 4.0872 - val_mean_absolute_error: 4.0872
# Epoch 5/25
# 1040/1040 [==============================] - 1s 561us/sample - loss: 3.5635 - mean_absolute_error: 3.5635 - val_loss: 4.2672 - val_mean_absolute_error: 4.2672
# Epoch 6/25
# 1040/1040 [==============================] - 1s 596us/sample - loss: 3.5473 - mean_absolute_error: 3.5473 - val_loss: 3.9718 - val_mean_absolute_error: 3.9718
# Epoch 7/25
# 1040/1040 [==============================] - 1s 596us/sample - loss: 3.5238 - mean_absolute_error: 3.5238 - val_loss: 3.8085 - val_mean_absolute_error: 3.8085
# Epoch 8/25
# 1040/1040 [==============================] - 1s 572us/sample - loss: 3.4883 - mean_absolute_error: 3.4883 - val_loss: 3.8462 - val_mean_absolute_error: 3.8462
# Epoch 9/25
# 1040/1040 [==============================] - 1s 583us/sample - loss: 3.5430 - mean_absolute_error: 3.5430 - val_loss: 3.8338 - val_mean_absolute_error: 3.8338
# Epoch 10/25
# 1040/1040 [==============================] - 1s 572us/sample - loss: 3.4221 - mean_absolute_error: 3.4221 - val_loss: 3.8773 - val_mean_absolute_error: 3.8773
# Epoch 11/25
# 1040/1040 [==============================] - 1s 566us/sample - loss: 3.5394 - mean_absolute_error: 3.5394 - val_loss: 4.5698 - val_mean_absolute_error: 4.5698
# 326/326 [==============================] - 1s 2ms/sample
# MAE:  3.6180528396500584  RMSE:  4.911772820186916  Runtime:  0:00:21.602643
#
# Trial number:  3
# Fold number:  2
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.1029 - mean_absolute_error: 4.1029 - val_loss: 3.8620 - val_mean_absolute_error: 3.8620
# Epoch 2/25
# 1040/1040 [==============================] - 1s 608us/sample - loss: 3.6604 - mean_absolute_error: 3.6604 - val_loss: 3.7984 - val_mean_absolute_error: 3.7984
# Epoch 3/25
# 1040/1040 [==============================] - 1s 589us/sample - loss: 3.6011 - mean_absolute_error: 3.6011 - val_loss: 4.3466 - val_mean_absolute_error: 4.3466
# Epoch 4/25
# 1040/1040 [==============================] - 1s 596us/sample - loss: 3.6132 - mean_absolute_error: 3.6132 - val_loss: 4.1254 - val_mean_absolute_error: 4.1254
# Epoch 5/25
# 1040/1040 [==============================] - 1s 587us/sample - loss: 3.5208 - mean_absolute_error: 3.5208 - val_loss: 4.4230 - val_mean_absolute_error: 4.4230
# Epoch 6/25
# 1040/1040 [==============================] - 1s 597us/sample - loss: 3.5286 - mean_absolute_error: 3.5286 - val_loss: 3.8420 - val_mean_absolute_error: 3.8420
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.937818744223851  RMSE:  5.176394196786248  Runtime:  0:00:19.682395
#
# Trial number:  3
# Fold number:  3
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 3.9160 - mean_absolute_error: 3.9160 - val_loss: 6.9739 - val_mean_absolute_error: 6.9739
# Epoch 2/25
# 1040/1040 [==============================] - 1s 597us/sample - loss: 3.6775 - mean_absolute_error: 3.6775 - val_loss: 4.5752 - val_mean_absolute_error: 4.5752
# Epoch 3/25
# 1040/1040 [==============================] - 1s 590us/sample - loss: 3.5875 - mean_absolute_error: 3.5875 - val_loss: 4.8061 - val_mean_absolute_error: 4.8061
# Epoch 4/25
# 1040/1040 [==============================] - 1s 592us/sample - loss: 3.5346 - mean_absolute_error: 3.5346 - val_loss: 4.1765 - val_mean_absolute_error: 4.1765
# Epoch 5/25
# 1040/1040 [==============================] - 1s 640us/sample - loss: 3.4938 - mean_absolute_error: 3.4938 - val_loss: 3.9144 - val_mean_absolute_error: 3.9144
# Epoch 6/25
# 1040/1040 [==============================] - 1s 590us/sample - loss: 3.4878 - mean_absolute_error: 3.4878 - val_loss: 4.0136 - val_mean_absolute_error: 4.0136
# Epoch 7/25
# 1040/1040 [==============================] - 1s 586us/sample - loss: 3.4647 - mean_absolute_error: 3.4647 - val_loss: 4.3104 - val_mean_absolute_error: 4.3104
# Epoch 8/25
# 1040/1040 [==============================] - 1s 631us/sample - loss: 3.4700 - mean_absolute_error: 3.4700 - val_loss: 3.8722 - val_mean_absolute_error: 3.8722
# Epoch 9/25
# 1040/1040 [==============================] - 1s 578us/sample - loss: 3.4434 - mean_absolute_error: 3.4434 - val_loss: 3.9437 - val_mean_absolute_error: 3.9437
# Epoch 10/25
# 1040/1040 [==============================] - 1s 614us/sample - loss: 3.4376 - mean_absolute_error: 3.4376 - val_loss: 3.8179 - val_mean_absolute_error: 3.8179
# Epoch 11/25
# 1040/1040 [==============================] - 1s 604us/sample - loss: 3.4272 - mean_absolute_error: 3.4272 - val_loss: 3.8428 - val_mean_absolute_error: 3.8428
# Epoch 12/25
# 1040/1040 [==============================] - 1s 605us/sample - loss: 3.3848 - mean_absolute_error: 3.3848 - val_loss: 3.9190 - val_mean_absolute_error: 3.9190
# Epoch 13/25
# 1040/1040 [==============================] - 1s 593us/sample - loss: 3.3704 - mean_absolute_error: 3.3704 - val_loss: 3.9359 - val_mean_absolute_error: 3.9359
# Epoch 14/25
# 1040/1040 [==============================] - 1s 591us/sample - loss: 3.3669 - mean_absolute_error: 3.3669 - val_loss: 4.0149 - val_mean_absolute_error: 4.0149
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.7960009905260343  RMSE:  5.154945901190783  Runtime:  0:00:24.475022
#
# Trial number:  3
# Fold number:  4
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.1668 - mean_absolute_error: 4.1668 - val_loss: 3.8658 - val_mean_absolute_error: 3.8658
# Epoch 2/25
# 1040/1040 [==============================] - 1s 705us/sample - loss: 3.7902 - mean_absolute_error: 3.7902 - val_loss: 3.6532 - val_mean_absolute_error: 3.6532
# Epoch 3/25
# 1040/1040 [==============================] - 1s 661us/sample - loss: 3.7763 - mean_absolute_error: 3.7763 - val_loss: 3.7562 - val_mean_absolute_error: 3.7562
# Epoch 4/25
# 1040/1040 [==============================] - 1s 605us/sample - loss: 3.6471 - mean_absolute_error: 3.6471 - val_loss: 3.9116 - val_mean_absolute_error: 3.9116
# Epoch 5/25
# 1040/1040 [==============================] - 1s 620us/sample - loss: 3.6132 - mean_absolute_error: 3.6132 - val_loss: 3.6286 - val_mean_absolute_error: 3.6286
# Epoch 6/25
# 1040/1040 [==============================] - 1s 586us/sample - loss: 3.6353 - mean_absolute_error: 3.6353 - val_loss: 3.6860 - val_mean_absolute_error: 3.6860
# Epoch 7/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.5531 - mean_absolute_error: 3.5531 - val_loss: 3.6357 - val_mean_absolute_error: 3.6357
# Epoch 8/25
# 1040/1040 [==============================] - 1s 584us/sample - loss: 3.6302 - mean_absolute_error: 3.6302 - val_loss: 3.8536 - val_mean_absolute_error: 3.8536
# Epoch 9/25
# 1040/1040 [==============================] - 1s 615us/sample - loss: 3.5646 - mean_absolute_error: 3.5646 - val_loss: 3.5755 - val_mean_absolute_error: 3.5755
# Epoch 10/25
# 1040/1040 [==============================] - 1s 606us/sample - loss: 3.5679 - mean_absolute_error: 3.5679 - val_loss: 3.6353 - val_mean_absolute_error: 3.6353
# Epoch 11/25
# 1040/1040 [==============================] - 1s 592us/sample - loss: 3.5404 - mean_absolute_error: 3.5404 - val_loss: 3.5797 - val_mean_absolute_error: 3.5797
# Epoch 12/25
# 1040/1040 [==============================] - 1s 601us/sample - loss: 3.4830 - mean_absolute_error: 3.4830 - val_loss: 3.6147 - val_mean_absolute_error: 3.6147
# Epoch 13/25
# 1040/1040 [==============================] - 1s 620us/sample - loss: 3.4984 - mean_absolute_error: 3.4984 - val_loss: 3.4787 - val_mean_absolute_error: 3.4787
# Epoch 14/25
# 1040/1040 [==============================] - 1s 610us/sample - loss: 3.5019 - mean_absolute_error: 3.5019 - val_loss: 3.4732 - val_mean_absolute_error: 3.4732
# Epoch 15/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.4747 - mean_absolute_error: 3.4747 - val_loss: 3.8378 - val_mean_absolute_error: 3.8378
# Epoch 16/25
# 1040/1040 [==============================] - 1s 590us/sample - loss: 3.4794 - mean_absolute_error: 3.4794 - val_loss: 3.4774 - val_mean_absolute_error: 3.4773
# Epoch 17/25
# 1040/1040 [==============================] - 1s 600us/sample - loss: 3.4785 - mean_absolute_error: 3.4785 - val_loss: 3.8666 - val_mean_absolute_error: 3.8666
# Epoch 18/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.4073 - mean_absolute_error: 3.4073 - val_loss: 3.6177 - val_mean_absolute_error: 3.6177
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.5538676859209173  RMSE:  4.9066449022024035  Runtime:  0:00:28.087693
#
# Trial number:  3
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.0797 - mean_absolute_error: 4.0797 - val_loss: 5.5411 - val_mean_absolute_error: 5.5411
# Epoch 2/25
# 1040/1040 [==============================] - 1s 643us/sample - loss: 3.7903 - mean_absolute_error: 3.7903 - val_loss: 4.1087 - val_mean_absolute_error: 4.1087
# Epoch 3/25
# 1040/1040 [==============================] - 1s 624us/sample - loss: 3.6614 - mean_absolute_error: 3.6614 - val_loss: 3.8969 - val_mean_absolute_error: 3.8969
# Epoch 4/25
# 1040/1040 [==============================] - 1s 621us/sample - loss: 3.7080 - mean_absolute_error: 3.7080 - val_loss: 4.0377 - val_mean_absolute_error: 4.0377
# Epoch 5/25
# 1040/1040 [==============================] - 1s 624us/sample - loss: 3.5824 - mean_absolute_error: 3.5824 - val_loss: 4.0431 - val_mean_absolute_error: 4.0431
# Epoch 6/25
# 1040/1040 [==============================] - 1s 607us/sample - loss: 3.5357 - mean_absolute_error: 3.5357 - val_loss: 4.7793 - val_mean_absolute_error: 4.7793
# Epoch 7/25
# 1040/1040 [==============================] - 1s 635us/sample - loss: 3.5592 - mean_absolute_error: 3.5592 - val_loss: 3.8700 - val_mean_absolute_error: 3.8700
# Epoch 8/25
# 1040/1040 [==============================] - 1s 616us/sample - loss: 3.5160 - mean_absolute_error: 3.5160 - val_loss: 4.4464 - val_mean_absolute_error: 4.4464
# Epoch 9/25
# 1040/1040 [==============================] - 1s 620us/sample - loss: 3.5172 - mean_absolute_error: 3.5172 - val_loss: 3.8129 - val_mean_absolute_error: 3.8129
# Epoch 10/25
# 1040/1040 [==============================] - 1s 628us/sample - loss: 3.5030 - mean_absolute_error: 3.5030 - val_loss: 3.7915 - val_mean_absolute_error: 3.7915
# Epoch 11/25
# 1040/1040 [==============================] - 1s 637us/sample - loss: 3.5114 - mean_absolute_error: 3.5114 - val_loss: 3.6017 - val_mean_absolute_error: 3.6017
# Epoch 12/25
# 1040/1040 [==============================] - 1s 614us/sample - loss: 3.4603 - mean_absolute_error: 3.4603 - val_loss: 3.8924 - val_mean_absolute_error: 3.8924
# Epoch 13/25
# 1040/1040 [==============================] - 1s 608us/sample - loss: 3.4328 - mean_absolute_error: 3.4328 - val_loss: 3.7207 - val_mean_absolute_error: 3.7207
# Epoch 14/25
# 1040/1040 [==============================] - 1s 594us/sample - loss: 3.5264 - mean_absolute_error: 3.5264 - val_loss: 3.9395 - val_mean_absolute_error: 3.9395
# Epoch 15/25
# 1040/1040 [==============================] - 1s 621us/sample - loss: 3.4823 - mean_absolute_error: 3.4823 - val_loss: 3.7799 - val_mean_absolute_error: 3.7799
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.4579940794875985  RMSE:  4.722310292793189  Runtime:  0:00:26.253247
#
# Trial number:  4
# Fold number:  1
# Train on 1040 samples, validate on 260 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.0455 - mean_absolute_error: 4.0455 - val_loss: 4.3222 - val_mean_absolute_error: 4.3222
# Epoch 2/25
# 1040/1040 [==============================] - 1s 635us/sample - loss: 3.6973 - mean_absolute_error: 3.6973 - val_loss: 4.0893 - val_mean_absolute_error: 4.0893
# Epoch 3/25
# 1040/1040 [==============================] - 1s 605us/sample - loss: 3.6534 - mean_absolute_error: 3.6534 - val_loss: 4.2410 - val_mean_absolute_error: 4.2410
# Epoch 4/25
# 1040/1040 [==============================] - 1s 616us/sample - loss: 3.5825 - mean_absolute_error: 3.5825 - val_loss: 4.2014 - val_mean_absolute_error: 4.2014
# Epoch 5/25
# 1040/1040 [==============================] - 1s 633us/sample - loss: 3.6223 - mean_absolute_error: 3.6223 - val_loss: 3.7875 - val_mean_absolute_error: 3.7875
# Epoch 6/25
# 1040/1040 [==============================] - 1s 609us/sample - loss: 3.5202 - mean_absolute_error: 3.5202 - val_loss: 4.5475 - val_mean_absolute_error: 4.5475
# Epoch 7/25
# 1040/1040 [==============================] - 1s 629us/sample - loss: 3.5290 - mean_absolute_error: 3.5290 - val_loss: 4.1233 - val_mean_absolute_error: 4.1233
# Epoch 8/25
# 1040/1040 [==============================] - 1s 659us/sample - loss: 3.5758 - mean_absolute_error: 3.5758 - val_loss: 3.8870 - val_mean_absolute_error: 3.8870
# Epoch 9/25
# 1040/1040 [==============================] - 1s 599us/sample - loss: 3.4194 - mean_absolute_error: 3.4194 - val_loss: 3.8450 - val_mean_absolute_error: 3.8450
# 326/326 [==============================] - 1s 2ms/sample
# MAE:  3.909266080634177  RMSE:  5.206852858003479  Runtime:  0:00:23.087429
#
# Trial number:  4
# Fold number:  2
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 3.9629 - mean_absolute_error: 3.9629 - val_loss: 5.6016 - val_mean_absolute_error: 5.6016
# Epoch 2/25
# 1040/1040 [==============================] - 1s 723us/sample - loss: 3.7489 - mean_absolute_error: 3.7489 - val_loss: 5.1277 - val_mean_absolute_error: 5.1277
# Epoch 3/25
# 1040/1040 [==============================] - 1s 728us/sample - loss: 3.5878 - mean_absolute_error: 3.5878 - val_loss: 4.4176 - val_mean_absolute_error: 4.4176
# Epoch 4/25
# 1040/1040 [==============================] - 1s 740us/sample - loss: 3.5933 - mean_absolute_error: 3.5933 - val_loss: 4.4816 - val_mean_absolute_error: 4.4816
# Epoch 5/25
# 1040/1040 [==============================] - 1s 726us/sample - loss: 3.4704 - mean_absolute_error: 3.4704 - val_loss: 4.1260 - val_mean_absolute_error: 4.1260
# Epoch 6/25
# 1040/1040 [==============================] - 1s 710us/sample - loss: 3.4673 - mean_absolute_error: 3.4673 - val_loss: 4.0002 - val_mean_absolute_error: 4.0002
# Epoch 7/25
# 1040/1040 [==============================] - 1s 643us/sample - loss: 3.4768 - mean_absolute_error: 3.4768 - val_loss: 3.9958 - val_mean_absolute_error: 3.9958
# Epoch 8/25
# 1040/1040 [==============================] - 1s 625us/sample - loss: 3.4744 - mean_absolute_error: 3.4744 - val_loss: 4.2003 - val_mean_absolute_error: 4.2003
# Epoch 9/25
# 1040/1040 [==============================] - 1s 630us/sample - loss: 3.4829 - mean_absolute_error: 3.4829 - val_loss: 3.8975 - val_mean_absolute_error: 3.8975
# Epoch 10/25
# 1040/1040 [==============================] - 1s 622us/sample - loss: 3.4322 - mean_absolute_error: 3.4322 - val_loss: 4.1929 - val_mean_absolute_error: 4.1929
# Epoch 11/25
# 1040/1040 [==============================] - 1s 638us/sample - loss: 3.4037 - mean_absolute_error: 3.4037 - val_loss: 3.7946 - val_mean_absolute_error: 3.7946
# Epoch 12/25
# 1040/1040 [==============================] - 1s 619us/sample - loss: 3.4544 - mean_absolute_error: 3.4544 - val_loss: 4.0241 - val_mean_absolute_error: 4.0241
# Epoch 13/25
# 1040/1040 [==============================] - 1s 665us/sample - loss: 3.3726 - mean_absolute_error: 3.3726 - val_loss: 4.0851 - val_mean_absolute_error: 4.0851
# Epoch 14/25
# 1040/1040 [==============================] - 1s 633us/sample - loss: 3.4321 - mean_absolute_error: 3.4321 - val_loss: 3.8620 - val_mean_absolute_error: 3.8620
# Epoch 15/25
# 1040/1040 [==============================] - 1s 630us/sample - loss: 3.3717 - mean_absolute_error: 3.3717 - val_loss: 3.7511 - val_mean_absolute_error: 3.7511
# Epoch 16/25
# 1040/1040 [==============================] - 1s 646us/sample - loss: 3.2666 - mean_absolute_error: 3.2666 - val_loss: 3.9965 - val_mean_absolute_error: 3.9965
# Epoch 17/25
# 1040/1040 [==============================] - 1s 659us/sample - loss: 3.4095 - mean_absolute_error: 3.4095 - val_loss: 3.7394 - val_mean_absolute_error: 3.7394
# Epoch 18/25
# 1040/1040 [==============================] - 1s 616us/sample - loss: 3.3559 - mean_absolute_error: 3.3559 - val_loss: 3.8475 - val_mean_absolute_error: 3.8475
# Epoch 19/25
# 1040/1040 [==============================] - 1s 643us/sample - loss: 3.2839 - mean_absolute_error: 3.2839 - val_loss: 3.7853 - val_mean_absolute_error: 3.7853
# Epoch 20/25
# 1040/1040 [==============================] - 1s 626us/sample - loss: 3.2954 - mean_absolute_error: 3.2954 - val_loss: 4.0920 - val_mean_absolute_error: 4.0920
# Epoch 21/25
# 1040/1040 [==============================] - 1s 616us/sample - loss: 3.3185 - mean_absolute_error: 3.3185 - val_loss: 3.7762 - val_mean_absolute_error: 3.7762
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.783496983272296  RMSE:  5.1293659628313995  Runtime:  0:00:31.973638
#
# Trial number:  4
# Fold number:  3
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.1029 - mean_absolute_error: 4.1029 - val_loss: 4.2825 - val_mean_absolute_error: 4.2825
# Epoch 2/25
# 1040/1040 [==============================] - 1s 652us/sample - loss: 3.6723 - mean_absolute_error: 3.6723 - val_loss: 4.2554 - val_mean_absolute_error: 4.2554
# Epoch 3/25
# 1040/1040 [==============================] - 1s 648us/sample - loss: 3.5750 - mean_absolute_error: 3.5750 - val_loss: 4.1998 - val_mean_absolute_error: 4.1998
# Epoch 4/25
# 1040/1040 [==============================] - 1s 666us/sample - loss: 3.6070 - mean_absolute_error: 3.6070 - val_loss: 4.1029 - val_mean_absolute_error: 4.1029
# Epoch 5/25
# 1040/1040 [==============================] - 1s 670us/sample - loss: 3.5634 - mean_absolute_error: 3.5634 - val_loss: 4.0012 - val_mean_absolute_error: 4.0012
# Epoch 6/25
# 1040/1040 [==============================] - 1s 620us/sample - loss: 3.5304 - mean_absolute_error: 3.5304 - val_loss: 4.1242 - val_mean_absolute_error: 4.1242
# Epoch 7/25
# 1040/1040 [==============================] - 1s 657us/sample - loss: 3.5286 - mean_absolute_error: 3.5286 - val_loss: 3.7346 - val_mean_absolute_error: 3.7346
# Epoch 8/25
# 1040/1040 [==============================] - 1s 628us/sample - loss: 3.4480 - mean_absolute_error: 3.4480 - val_loss: 4.0576 - val_mean_absolute_error: 4.0576
# Epoch 9/25
# 1040/1040 [==============================] - 1s 615us/sample - loss: 3.4947 - mean_absolute_error: 3.4948 - val_loss: 3.8675 - val_mean_absolute_error: 3.8675
# Epoch 10/25
# 1040/1040 [==============================] - 1s 623us/sample - loss: 3.3907 - mean_absolute_error: 3.3907 - val_loss: 4.4064 - val_mean_absolute_error: 4.4064
# Epoch 11/25
# 1040/1040 [==============================] - 1s 636us/sample - loss: 3.3740 - mean_absolute_error: 3.3740 - val_loss: 3.6755 - val_mean_absolute_error: 3.6755
# Epoch 12/25
# 1040/1040 [==============================] - 1s 632us/sample - loss: 3.4094 - mean_absolute_error: 3.4094 - val_loss: 3.6830 - val_mean_absolute_error: 3.6830
# Epoch 13/25
# 1040/1040 [==============================] - 1s 628us/sample - loss: 3.3914 - mean_absolute_error: 3.3914 - val_loss: 3.7800 - val_mean_absolute_error: 3.7800
# Epoch 14/25
# 1040/1040 [==============================] - 1s 614us/sample - loss: 3.3928 - mean_absolute_error: 3.3928 - val_loss: 3.8124 - val_mean_absolute_error: 3.8124
# Epoch 15/25
# 1040/1040 [==============================] - 1s 636us/sample - loss: 3.3159 - mean_absolute_error: 3.3159 - val_loss: 3.9841 - val_mean_absolute_error: 3.9841
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.803097865565465  RMSE:  5.118589316231396  Runtime:  0:00:27.669047
#
# Trial number:  4
# Fold number:  4
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.2149 - mean_absolute_error: 4.2149 - val_loss: 4.0718 - val_mean_absolute_error: 4.0718
# Epoch 2/25
# 1040/1040 [==============================] - 1s 573us/sample - loss: 3.8128 - mean_absolute_error: 3.8128 - val_loss: 4.8092 - val_mean_absolute_error: 4.8092
# Epoch 3/25
# 1040/1040 [==============================] - 1s 612us/sample - loss: 3.7071 - mean_absolute_error: 3.7071 - val_loss: 4.7240 - val_mean_absolute_error: 4.7240
# Epoch 4/25
# 1040/1040 [==============================] - 1s 591us/sample - loss: 3.6696 - mean_absolute_error: 3.6696 - val_loss: 4.0036 - val_mean_absolute_error: 4.0036
# Epoch 5/25
# 1040/1040 [==============================] - 1s 588us/sample - loss: 3.6707 - mean_absolute_error: 3.6707 - val_loss: 3.9306 - val_mean_absolute_error: 3.9306
# Epoch 6/25
# 1040/1040 [==============================] - 1s 596us/sample - loss: 3.6803 - mean_absolute_error: 3.6803 - val_loss: 3.6766 - val_mean_absolute_error: 3.6766
# Epoch 7/25
# 1040/1040 [==============================] - 1s 583us/sample - loss: 3.6201 - mean_absolute_error: 3.6201 - val_loss: 4.0158 - val_mean_absolute_error: 4.0158
# Epoch 8/25
# 1040/1040 [==============================] - 1s 590us/sample - loss: 3.5757 - mean_absolute_error: 3.5757 - val_loss: 4.1746 - val_mean_absolute_error: 4.1746
# Epoch 9/25
# 1040/1040 [==============================] - 1s 576us/sample - loss: 3.5366 - mean_absolute_error: 3.5366 - val_loss: 4.0267 - val_mean_absolute_error: 4.0267
# Epoch 10/25
# 1040/1040 [==============================] - 1s 591us/sample - loss: 3.5385 - mean_absolute_error: 3.5385 - val_loss: 3.7080 - val_mean_absolute_error: 3.7080
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.515161476061894  RMSE:  4.605251401470039  Runtime:  0:00:24.929052
#
# Trial number:  4
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 3.9350 - mean_absolute_error: 3.9350 - val_loss: 4.0830 - val_mean_absolute_error: 4.0830
# Epoch 2/25
# 1040/1040 [==============================] - 1s 611us/sample - loss: 3.6604 - mean_absolute_error: 3.6604 - val_loss: 5.3305 - val_mean_absolute_error: 5.3305
# Epoch 3/25
# 1040/1040 [==============================] - 1s 586us/sample - loss: 3.5667 - mean_absolute_error: 3.5667 - val_loss: 4.2198 - val_mean_absolute_error: 4.2198
# Epoch 4/25
# 1040/1040 [==============================] - 1s 599us/sample - loss: 3.4596 - mean_absolute_error: 3.4596 - val_loss: 4.3583 - val_mean_absolute_error: 4.3583
# Epoch 5/25
# 1040/1040 [==============================] - 1s 580us/sample - loss: 3.4272 - mean_absolute_error: 3.4272 - val_loss: 4.4050 - val_mean_absolute_error: 4.4050
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.882125015659974  RMSE:  5.345837232577596  Runtime:  0:00:22.410133
#
# Trial number:  5
# Fold number:  1
# Train on 1040 samples, validate on 260 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.0417 - mean_absolute_error: 4.0417 - val_loss: 3.7895 - val_mean_absolute_error: 3.7895
# Epoch 2/25
# 1040/1040 [==============================] - 1s 587us/sample - loss: 3.7163 - mean_absolute_error: 3.7163 - val_loss: 4.1028 - val_mean_absolute_error: 4.1028
# Epoch 3/25
# 1040/1040 [==============================] - 1s 569us/sample - loss: 3.6658 - mean_absolute_error: 3.6658 - val_loss: 4.2443 - val_mean_absolute_error: 4.2443
# Epoch 4/25
# 1040/1040 [==============================] - 1s 606us/sample - loss: 3.6273 - mean_absolute_error: 3.6273 - val_loss: 3.7150 - val_mean_absolute_error: 3.7150
# Epoch 5/25
# 1040/1040 [==============================] - 1s 582us/sample - loss: 3.5408 - mean_absolute_error: 3.5408 - val_loss: 4.0030 - val_mean_absolute_error: 4.0030
# Epoch 6/25
# 1040/1040 [==============================] - 1s 589us/sample - loss: 3.5848 - mean_absolute_error: 3.5848 - val_loss: 4.1815 - val_mean_absolute_error: 4.1815
# Epoch 7/25
# 1040/1040 [==============================] - 1s 638us/sample - loss: 3.5428 - mean_absolute_error: 3.5428 - val_loss: 4.1846 - val_mean_absolute_error: 4.1846
# Epoch 8/25
# 1040/1040 [==============================] - 1s 576us/sample - loss: 3.5606 - mean_absolute_error: 3.5606 - val_loss: 3.8201 - val_mean_absolute_error: 3.8201
# 326/326 [==============================] - 1s 2ms/sample
# MAE:  3.790408096348216  RMSE:  5.176231063634606  Runtime:  0:00:24.363108
#
# Trial number:  5
# Fold number:  2
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 4s 4ms/sample - loss: 4.0770 - mean_absolute_error: 4.0770 - val_loss: 5.8742 - val_mean_absolute_error: 5.8742
# Epoch 2/25
# 1040/1040 [==============================] - 1s 601us/sample - loss: 3.7560 - mean_absolute_error: 3.7560 - val_loss: 4.4969 - val_mean_absolute_error: 4.4969
# Epoch 3/25
# 1040/1040 [==============================] - 1s 604us/sample - loss: 3.6912 - mean_absolute_error: 3.6912 - val_loss: 4.4575 - val_mean_absolute_error: 4.4575
# Epoch 4/25
# 1040/1040 [==============================] - 1s 597us/sample - loss: 3.6022 - mean_absolute_error: 3.6022 - val_loss: 4.6217 - val_mean_absolute_error: 4.6217
# Epoch 5/25
# 1040/1040 [==============================] - 1s 605us/sample - loss: 3.5613 - mean_absolute_error: 3.5613 - val_loss: 4.2268 - val_mean_absolute_error: 4.2268
# Epoch 6/25
# 1040/1040 [==============================] - 1s 616us/sample - loss: 3.6108 - mean_absolute_error: 3.6108 - val_loss: 4.0813 - val_mean_absolute_error: 4.0813
# Epoch 7/25
# 1040/1040 [==============================] - 1s 600us/sample - loss: 3.5038 - mean_absolute_error: 3.5038 - val_loss: 5.4199 - val_mean_absolute_error: 5.4199
# Epoch 8/25
# 1040/1040 [==============================] - 1s 597us/sample - loss: 3.5089 - mean_absolute_error: 3.5089 - val_loss: 4.5502 - val_mean_absolute_error: 4.5502
# Epoch 9/25
# 1040/1040 [==============================] - 1s 605us/sample - loss: 3.5080 - mean_absolute_error: 3.5080 - val_loss: 4.0082 - val_mean_absolute_error: 4.0082
# Epoch 10/25
# 1040/1040 [==============================] - 1s 574us/sample - loss: 3.5315 - mean_absolute_error: 3.5315 - val_loss: 4.1586 - val_mean_absolute_error: 4.1586
# Epoch 11/25
# 1040/1040 [==============================] - 1s 591us/sample - loss: 3.4741 - mean_absolute_error: 3.4741 - val_loss: 4.5192 - val_mean_absolute_error: 4.5192
# Epoch 12/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.4622 - mean_absolute_error: 3.4622 - val_loss: 4.2741 - val_mean_absolute_error: 4.2741
# Epoch 13/25
# 1040/1040 [==============================] - 1s 596us/sample - loss: 3.3910 - mean_absolute_error: 3.3910 - val_loss: 4.1177 - val_mean_absolute_error: 4.1177
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.3995465184358453  RMSE:  4.529308529286353  Runtime:  0:00:27.549871
#
# Trial number:  5
# Fold number:  3
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 4ms/sample - loss: 4.1402 - mean_absolute_error: 4.1402 - val_loss: 3.8586 - val_mean_absolute_error: 3.8586
# Epoch 2/25
# 1040/1040 [==============================] - 1s 699us/sample - loss: 3.8334 - mean_absolute_error: 3.8334 - val_loss: 3.3316 - val_mean_absolute_error: 3.3316
# Epoch 3/25
# 1040/1040 [==============================] - 1s 659us/sample - loss: 3.7036 - mean_absolute_error: 3.7036 - val_loss: 4.0028 - val_mean_absolute_error: 4.0028
# Epoch 4/25
# 1040/1040 [==============================] - 1s 685us/sample - loss: 3.6711 - mean_absolute_error: 3.6711 - val_loss: 3.5334 - val_mean_absolute_error: 3.5334
# Epoch 5/25
# 1040/1040 [==============================] - 1s 688us/sample - loss: 3.6723 - mean_absolute_error: 3.6723 - val_loss: 3.4230 - val_mean_absolute_error: 3.4230
# Epoch 6/25
# 1040/1040 [==============================] - 1s 652us/sample - loss: 3.6359 - mean_absolute_error: 3.6359 - val_loss: 4.0840 - val_mean_absolute_error: 4.0840
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.7138820157051087  RMSE:  4.961233427745676  Runtime:  0:00:24.177753
#
# Trial number:  5
# Fold number:  4
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 4.0953 - mean_absolute_error: 4.0953 - val_loss: 4.1722 - val_mean_absolute_error: 4.1722
# Epoch 2/25
# 1040/1040 [==============================] - 1s 627us/sample - loss: 3.7717 - mean_absolute_error: 3.7717 - val_loss: 4.2245 - val_mean_absolute_error: 4.2245
# Epoch 3/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.6598 - mean_absolute_error: 3.6598 - val_loss: 4.6507 - val_mean_absolute_error: 4.6507
# Epoch 4/25
# 1040/1040 [==============================] - 1s 642us/sample - loss: 3.6614 - mean_absolute_error: 3.6614 - val_loss: 3.5546 - val_mean_absolute_error: 3.5546
# Epoch 5/25
# 1040/1040 [==============================] - 1s 616us/sample - loss: 3.5863 - mean_absolute_error: 3.5863 - val_loss: 3.6678 - val_mean_absolute_error: 3.6678
# Epoch 6/25
# 1040/1040 [==============================] - 1s 617us/sample - loss: 3.5922 - mean_absolute_error: 3.5922 - val_loss: 3.6114 - val_mean_absolute_error: 3.6114
# Epoch 7/25
# 1040/1040 [==============================] - 1s 610us/sample - loss: 3.6234 - mean_absolute_error: 3.6234 - val_loss: 3.7142 - val_mean_absolute_error: 3.7142
# Epoch 8/25
# 1040/1040 [==============================] - 1s 630us/sample - loss: 3.5547 - mean_absolute_error: 3.5547 - val_loss: 3.4702 - val_mean_absolute_error: 3.4702
# Epoch 9/25
# 1040/1040 [==============================] - 1s 613us/sample - loss: 3.5182 - mean_absolute_error: 3.5182 - val_loss: 4.2082 - val_mean_absolute_error: 4.2082
# Epoch 10/25
# 1040/1040 [==============================] - 1s 638us/sample - loss: 3.4823 - mean_absolute_error: 3.4823 - val_loss: 3.5294 - val_mean_absolute_error: 3.5294
# Epoch 11/25
# 1040/1040 [==============================] - 1s 601us/sample - loss: 3.4502 - mean_absolute_error: 3.4502 - val_loss: 3.9138 - val_mean_absolute_error: 3.9138
# Epoch 12/25
# 1040/1040 [==============================] - 1s 620us/sample - loss: 3.4955 - mean_absolute_error: 3.4955 - val_loss: 3.6441 - val_mean_absolute_error: 3.6441
# 325/325 [==============================] - 1s 2ms/sample
# MAE:  3.7366168935665716  RMSE:  4.912749581084562  Runtime:  0:00:28.860327
#
# Trial number:  5
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# ...
# Epoch 6/25
# 1040/1040 [==============================] - 1s 654us/sample - loss: 3.6264 - mean_absolute_error: 3.6264 - val_loss: 4.3929 - val_mean_absolute_error: 4.3929
# Epoch 7/25
# 1040/1040 [==============================] - 1s 656us/sample - loss: 3.6048 - mean_absolute_error: 3.6048 - val_loss: 4.0071 - val_mean_absolute_error: 4.0071
# Epoch 8/25
# 1040/1040 [==============================] - 1s 686us/sample - loss: 3.6646 - mean_absolute_error: 3.6646 - val_loss: 3.5170 - val_mean_absolute_error: 3.5170
# Epoch 9/25
# 1040/1040 [==============================] - 1s 689us/sample - loss: 3.5638 - mean_absolute_error: 3.5638 - val_loss: 3.5890 - val_mean_absolute_error: 3.5890
# Epoch 10/25
# 1040/1040 [==============================] - 1s 659us/sample - loss: 3.6223 - mean_absolute_error: 3.6223 - val_loss: 3.6348 - val_mean_absolute_error: 3.6348
# Epoch 11/25
# 1040/1040 [==============================] - 1s 660us/sample - loss: 3.6144 - mean_absolute_error: 3.6144 - val_loss: 3.9398 - val_mean_absolute_error: 3.9398
# Epoch 12/25
# 1040/1040 [==============================] - 1s 646us/sample - loss: 3.5646 - mean_absolute_error: 3.5646 - val_loss: 3.6333 - val_mean_absolute_error: 3.6333
# 325/325 [==============================] - 1s 3ms/sample
# MAE:  3.4521083448987744  RMSE:  4.579624234598627  Runtime:  0:00:31.580156
#
# Trial number:  6
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 4.0498 - mean_absolute_error: 4.0498 - val_loss: 4.6933 - val_mean_absolute_error: 4.6933
# Epoch 2/25
# 1040/1040 [==============================] - 1s 662us/sample - loss: 3.6883 - mean_absolute_error: 3.6883 - val_loss: 4.5025 - val_mean_absolute_error: 4.5025
# Epoch 3/25
# 1040/1040 [==============================] - 1s 689us/sample - loss: 3.7402 - mean_absolute_error: 3.7402 - val_loss: 3.9878 - val_mean_absolute_error: 3.9878
# Epoch 4/25
# 1040/1040 [==============================] - 1s 685us/sample - loss: 3.5986 - mean_absolute_error: 3.5986 - val_loss: 3.9002 - val_mean_absolute_error: 3.9002
# Epoch 5/25
# 1040/1040 [==============================] - 1s 662us/sample - loss: 3.5927 - mean_absolute_error: 3.5927 - val_loss: 3.8621 - val_mean_absolute_error: 3.8620
# Epoch 6/25
# 1040/1040 [==============================] - 1s 658us/sample - loss: 3.5224 - mean_absolute_error: 3.5224 - val_loss: 3.9606 - val_mean_absolute_error: 3.9606
# Epoch 7/25
# 1040/1040 [==============================] - 1s 692us/sample - loss: 3.5360 - mean_absolute_error: 3.5360 - val_loss: 3.8236 - val_mean_absolute_error: 3.8236
# Epoch 8/25
# 1040/1040 [==============================] - 1s 665us/sample - loss: 3.5206 - mean_absolute_error: 3.5206 - val_loss: 4.2138 - val_mean_absolute_error: 4.2138
# Epoch 9/25
# 1040/1040 [==============================] - 1s 671us/sample - loss: 3.5211 - mean_absolute_error: 3.5211 - val_loss: 3.9216 - val_mean_absolute_error: 3.9216
# Epoch 10/25
# 1040/1040 [==============================] - 1s 649us/sample - loss: 3.4613 - mean_absolute_error: 3.4613 - val_loss: 3.8309 - val_mean_absolute_error: 3.8309
# Epoch 11/25
# 1040/1040 [==============================] - 1s 642us/sample - loss: 3.5003 - mean_absolute_error: 3.5003 - val_loss: 4.1492 - val_mean_absolute_error: 4.1492
# 325/325 [==============================] - 1s 3ms/sample
# MAE:  3.6453730681607355  RMSE:  4.636344602021789  Runtime:  0:00:30.669487
#
# Trial number:  7
# Fold number:  1
# Train on 1040 samples, validate on 260 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 3.9107 - mean_absolute_error: 3.9107 - val_loss: 4.8680 - val_mean_absolute_error: 4.8680
# Epoch 2/25
# 1040/1040 [==============================] - 1s 676us/sample - loss: 3.6243 - mean_absolute_error: 3.6243 - val_loss: 4.4455 - val_mean_absolute_error: 4.4455
# Epoch 3/25
# 1040/1040 [==============================] - 1s 686us/sample - loss: 3.6276 - mean_absolute_error: 3.6276 - val_loss: 4.2333 - val_mean_absolute_error: 4.2333
# Epoch 4/25
# 1040/1040 [==============================] - 1s 689us/sample - loss: 3.6056 - mean_absolute_error: 3.6056 - val_loss: 4.0359 - val_mean_absolute_error: 4.0359
# Epoch 5/25
# 1040/1040 [==============================] - 1s 719us/sample - loss: 3.5154 - mean_absolute_error: 3.5154 - val_loss: 4.5129 - val_mean_absolute_error: 4.5129
# Epoch 6/25
# 1040/1040 [==============================] - 1s 784us/sample - loss: 3.4869 - mean_absolute_error: 3.4869 - val_loss: 4.0354 - val_mean_absolute_error: 4.0354
# Epoch 7/25
# 1040/1040 [==============================] - 1s 767us/sample - loss: 3.4530 - mean_absolute_error: 3.4530 - val_loss: 3.8781 - val_mean_absolute_error: 3.8781
# Epoch 8/25
# 1040/1040 [==============================] - 1s 743us/sample - loss: 3.4758 - mean_absolute_error: 3.4758 - val_loss: 3.9886 - val_mean_absolute_error: 3.9886
# Epoch 9/25
# 1040/1040 [==============================] - 1s 746us/sample - loss: 3.4650 - mean_absolute_error: 3.4650 - val_loss: 4.1657 - val_mean_absolute_error: 4.1657
# Epoch 10/25
# 1040/1040 [==============================] - 1s 752us/sample - loss: 3.4332 - mean_absolute_error: 3.4332 - val_loss: 3.6989 - val_mean_absolute_error: 3.6989
# Epoch 11/25
# 1040/1040 [==============================] - 1s 732us/sample - loss: 3.3961 - mean_absolute_error: 3.3961 - val_loss: 4.3763 - val_mean_absolute_error: 4.3763
# Epoch 12/25
# 1040/1040 [==============================] - 1s 741us/sample - loss: 3.4298 - mean_absolute_error: 3.4298 - val_loss: 3.9035 - val_mean_absolute_error: 3.9035
# Epoch 13/25
# 1040/1040 [==============================] - 1s 749us/sample - loss: 3.3951 - mean_absolute_error: 3.3951 - val_loss: 3.8589 - val_mean_absolute_error: 3.8589
# Epoch 14/25
# 1040/1040 [==============================] - 1s 732us/sample - loss: 3.4172 - mean_absolute_error: 3.4172 - val_loss: 3.8823 - val_mean_absolute_error: 3.8823
# 326/326 [==============================] - 1s 3ms/sample
# MAE:  3.7094903006235516  RMSE:  5.01214188061365  Runtime:  0:00:34.265402
#
# Trial number:  7
# Fold number:  2
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 4.1237 - mean_absolute_error: 4.1237 - val_loss: 4.3552 - val_mean_absolute_error: 4.3552
# Epoch 2/25
# 1040/1040 [==============================] - 1s 686us/sample - loss: 3.8034 - mean_absolute_error: 3.8034 - val_loss: 4.8361 - val_mean_absolute_error: 4.8361
# Epoch 3/25
# 1040/1040 [==============================] - 1s 688us/sample - loss: 3.7212 - mean_absolute_error: 3.7212 - val_loss: 3.7619 - val_mean_absolute_error: 3.7619
# Epoch 4/25
# 1040/1040 [==============================] - 1s 713us/sample - loss: 3.7009 - mean_absolute_error: 3.7009 - val_loss: 4.0149 - val_mean_absolute_error: 4.0149
# Epoch 5/25
# 1040/1040 [==============================] - 1s 692us/sample - loss: 3.5994 - mean_absolute_error: 3.5994 - val_loss: 4.1947 - val_mean_absolute_error: 4.1947
# Epoch 6/25
# 1040/1040 [==============================] - 1s 686us/sample - loss: 3.5546 - mean_absolute_error: 3.5546 - val_loss: 3.7531 - val_mean_absolute_error: 3.7531
# Epoch 7/25
# 1040/1040 [==============================] - 1s 668us/sample - loss: 3.5770 - mean_absolute_error: 3.5770 - val_loss: 4.1424 - val_mean_absolute_error: 4.1424
# Epoch 8/25
# 1040/1040 [==============================] - 1s 671us/sample - loss: 3.5781 - mean_absolute_error: 3.5781 - val_loss: 3.9603 - val_mean_absolute_error: 3.9603
# Epoch 9/25
# 1040/1040 [==============================] - 1s 696us/sample - loss: 3.5628 - mean_absolute_error: 3.5628 - val_loss: 3.7480 - val_mean_absolute_error: 3.7480
# Epoch 10/25
# 1040/1040 [==============================] - 1s 670us/sample - loss: 3.5153 - mean_absolute_error: 3.5153 - val_loss: 3.9613 - val_mean_absolute_error: 3.9613
# Epoch 11/25
# 1040/1040 [==============================] - 1s 678us/sample - loss: 3.5256 - mean_absolute_error: 3.5256 - val_loss: 3.7229 - val_mean_absolute_error: 3.7229
# Epoch 12/25
# 1040/1040 [==============================] - 1s 672us/sample - loss: 3.4509 - mean_absolute_error: 3.4509 - val_loss: 3.8114 - val_mean_absolute_error: 3.8114
# Epoch 13/25
# 1040/1040 [==============================] - 1s 671us/sample - loss: 3.5296 - mean_absolute_error: 3.5296 - val_loss: 3.9276 - val_mean_absolute_error: 3.9276
# Epoch 14/25
# 1040/1040 [==============================] - 1s 650us/sample - loss: 3.5074 - mean_absolute_error: 3.5074 - val_loss: 3.7683 - val_mean_absolute_error: 3.7683
# Epoch 15/25
# 1040/1040 [==============================] - 1s 668us/sample - loss: 3.4444 - mean_absolute_error: 3.4444 - val_loss: 3.9094 - val_mean_absolute_error: 3.9094
# 325/325 [==============================] - 1s 3ms/sample
# MAE:  3.5799064658100788  RMSE:  4.9043086690496756  Runtime:  0:00:34.628758
#
# Trial number:  7
# Fold number:  3
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 3.9028 - mean_absolute_error: 3.9028 - val_loss: 4.1138 - val_mean_absolute_error: 4.1138
# Epoch 2/25
# 1040/1040 [==============================] - 1s 699us/sample - loss: 3.6236 - mean_absolute_error: 3.6236 - val_loss: 3.9960 - val_mean_absolute_error: 3.9960
# Epoch 3/25
# 1040/1040 [==============================] - 1s 681us/sample - loss: 3.5049 - mean_absolute_error: 3.5049 - val_loss: 4.2397 - val_mean_absolute_error: 4.2397
# Epoch 4/25
# 1040/1040 [==============================] - 1s 694us/sample - loss: 3.5051 - mean_absolute_error: 3.5051 - val_loss: 5.5595 - val_mean_absolute_error: 5.5595
# Epoch 5/25
# 1040/1040 [==============================] - 1s 689us/sample - loss: 3.4617 - mean_absolute_error: 3.4617 - val_loss: 4.1972 - val_mean_absolute_error: 4.1972
# Epoch 6/25
# 1040/1040 [==============================] - 1s 721us/sample - loss: 3.4148 - mean_absolute_error: 3.4148 - val_loss: 3.9413 - val_mean_absolute_error: 3.9413
# Epoch 7/25
# 1040/1040 [==============================] - 1s 703us/sample - loss: 3.4395 - mean_absolute_error: 3.4395 - val_loss: 3.8535 - val_mean_absolute_error: 3.8535
# Epoch 8/25
# 1040/1040 [==============================] - 1s 663us/sample - loss: 3.4078 - mean_absolute_error: 3.4078 - val_loss: 3.8993 - val_mean_absolute_error: 3.8993
# Epoch 9/25
# 1040/1040 [==============================] - 1s 680us/sample - loss: 3.3601 - mean_absolute_error: 3.3601 - val_loss: 4.0901 - val_mean_absolute_error: 4.0901
# Epoch 10/25
# 1040/1040 [==============================] - 1s 695us/sample - loss: 3.3077 - mean_absolute_error: 3.3077 - val_loss: 3.8620 - val_mean_absolute_error: 3.8620
# Epoch 11/25
# 1040/1040 [==============================] - 1s 681us/sample - loss: 3.3604 - mean_absolute_error: 3.3604 - val_loss: 3.9368 - val_mean_absolute_error: 3.9368
# 325/325 [==============================] - 1s 3ms/sample
# MAE:  3.9086374901932013  RMSE:  5.224509059924435  Runtime:  0:00:32.556011
#
# Trial number:  7
# Fold number:  4
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 4.1326 - mean_absolute_error: 4.1326 - val_loss: 3.7368 - val_mean_absolute_error: 3.7368
# Epoch 2/25
# 1040/1040 [==============================] - 1s 687us/sample - loss: 3.8207 - mean_absolute_error: 3.8207 - val_loss: 4.0354 - val_mean_absolute_error: 4.0354
# Epoch 3/25
# 1040/1040 [==============================] - 1s 681us/sample - loss: 3.7320 - mean_absolute_error: 3.7320 - val_loss: 3.7671 - val_mean_absolute_error: 3.7671
# Epoch 4/25
# 1040/1040 [==============================] - 1s 666us/sample - loss: 3.7124 - mean_absolute_error: 3.7124 - val_loss: 3.7385 - val_mean_absolute_error: 3.7385
# Epoch 5/25
# 1040/1040 [==============================] - 1s 708us/sample - loss: 3.6301 - mean_absolute_error: 3.6301 - val_loss: 3.6770 - val_mean_absolute_error: 3.6770
# Epoch 6/25
# 1040/1040 [==============================] - 1s 704us/sample - loss: 3.6510 - mean_absolute_error: 3.6510 - val_loss: 3.8167 - val_mean_absolute_error: 3.8167
# Epoch 7/25
# 1040/1040 [==============================] - 1s 704us/sample - loss: 3.5402 - mean_absolute_error: 3.5402 - val_loss: 3.6291 - val_mean_absolute_error: 3.6291
# Epoch 8/25
# 1040/1040 [==============================] - 1s 669us/sample - loss: 3.5859 - mean_absolute_error: 3.5859 - val_loss: 4.6674 - val_mean_absolute_error: 4.6674
# Epoch 9/25
# 1040/1040 [==============================] - 1s 670us/sample - loss: 3.5318 - mean_absolute_error: 3.5318 - val_loss: 4.0328 - val_mean_absolute_error: 4.0328
# Epoch 10/25
# 1040/1040 [==============================] - 1s 686us/sample - loss: 3.5747 - mean_absolute_error: 3.5747 - val_loss: 3.6628 - val_mean_absolute_error: 3.6628
# Epoch 11/25
# 1040/1040 [==============================] - 1s 693us/sample - loss: 3.5264 - mean_absolute_error: 3.5264 - val_loss: 3.6038 - val_mean_absolute_error: 3.6038
# Epoch 12/25
# 1040/1040 [==============================] - 1s 691us/sample - loss: 3.4412 - mean_absolute_error: 3.4412 - val_loss: 3.6696 - val_mean_absolute_error: 3.6696
# Epoch 13/25
# 1040/1040 [==============================] - 1s 721us/sample - loss: 3.4642 - mean_absolute_error: 3.4642 - val_loss: 3.5221 - val_mean_absolute_error: 3.5221
# Epoch 14/25
# 1040/1040 [==============================] - 1s 682us/sample - loss: 3.4700 - mean_absolute_error: 3.4700 - val_loss: 3.8384 - val_mean_absolute_error: 3.8384
# Epoch 15/25
# 1040/1040 [==============================] - 1s 695us/sample - loss: 3.4872 - mean_absolute_error: 3.4872 - val_loss: 3.8725 - val_mean_absolute_error: 3.8725
# Epoch 16/25
# 1040/1040 [==============================] - 1s 684us/sample - loss: 3.4385 - mean_absolute_error: 3.4385 - val_loss: 3.6611 - val_mean_absolute_error: 3.6611
# Epoch 17/25
# 1040/1040 [==============================] - 1s 686us/sample - loss: 3.4146 - mean_absolute_error: 3.4146 - val_loss: 3.6353 - val_mean_absolute_error: 3.6353
# 325/325 [==============================] - 1s 3ms/sample
# MAE:  3.5936259020498165  RMSE:  4.696158842986168  Runtime:  0:00:38.296700
#
# Trial number:  7
# Fold number:  5
# Train on 1040 samples, validate on 261 samples
# Epoch 1/25
# 1040/1040 [==============================] - 5s 5ms/sample - loss: 3.9922 - mean_absolute_error: 3.9922 - val_loss: 5.1366 - val_mean_absolute_error: 5.1366
# Epoch 2/25
# 1040/1040 [==============================] - 1s 611us/sample - loss: 3.8051 - mean_absolute_error: 3.8051 - val_loss: 3.6954 - val_mean_absolute_error: 3.6954
# Epoch 3/25
# 1040/1040 [==============================] - 1s 603us/sample - loss: 3.7637 - mean_absolute_error: 3.7637 - val_loss: 3.9337 - val_mean_absolute_error: 3.9337
# Epoch 4/25
# 1040/1040 [==============================] - 1s 594us/sample - loss: 3.6792 - mean_absolute_error: 3.6792 - val_loss: 3.7362 - val_mean_absolute_error: 3.7362
# Epoch 5/25
# 1040/1040 [==============================] - 1s 625us/sample - loss: 3.6018 - mean_absolute_error: 3.6018 - val_loss: 3.6755 - val_mean_absolute_error: 3.6755
# Epoch 6/25
# 1040/1040 [==============================] - 1s 623us/sample - loss: 3.5942 - mean_absolute_error: 3.5942 - val_loss: 3.6501 - val_mean_absolute_error: 3.6501
# Epoch 7/25
# 1040/1040 [==============================] - 1s 602us/sample - loss: 3.6310 - mean_absolute_error: 3.6310 - val_loss: 3.9061 - val_mean_absolute_error: 3.9061
# Epoch 8/25
# 1040/1040 [==============================] - 1s 600us/sample - loss: 3.5966 - mean_absolute_error: 3.5966 - val_loss: 3.6708 - val_mean_absolute_error: 3.6708
# Epoch 9/25
# 1040/1040 [==============================] - 1s 615us/sample - loss: 3.5257 - mean_absolute_error: 3.5257 - val_loss: 3.8505 - val_mean_absolute_error: 3.8505
# Epoch 10/25
# 1040/1040 [==============================] - 1s 584us/sample - loss: 3.4608 - mean_absolute_error: 3.4608 - val_loss: 3.8892 - val_mean_absolute_error: 3.8892
# 325/325 [==============================] - 1s 3ms/sample
# MAE:  3.5155737156684586  RMSE:  4.73377725069702  Runtime:  0:00:32.765396

# %%
results.to_csv(table_loc+"pretrain_cont_results_table.csv")

# %%
results.describe()
# Out:
#        scores_mae  scores_rmse
# count   35.000000    35.000000
# mean     3.705597     4.968560
# std      0.170001     0.245597
# min      3.399547     4.529309
# 25%      3.569561     4.777363
# 50%      3.713882     4.961233
# 75%      3.840561     5.176313
# max      3.975770     5.345837

# %% [markdown]
# ##Results

# %% [markdown]
# *  Model fully_connected_512: 3.733756 MAE, 4.968560 RMSE
